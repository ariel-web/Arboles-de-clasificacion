# %% [markdown]
# Aprendizaje Supervizado
#
# Determinando a partir de un conjunto de datos si un animal es perro o gato
#
# Tabla de Datos
#
# ![fgghhhtr (2).png](data:image/png;base64,...)

# %%
from sklearn import tree
Feature = [[7,0.6,40],[7,0.6,41],[37,0.8,37],[37,0.8,38]]
labels = [0,0,1,1]

# %%
classifier = tree.DecisionTreeClassifier()
classifier.fit(features, labels)
res = classifier.predict([(7,0.6,41)])
print (res)

# %%
# Out:
# 0
